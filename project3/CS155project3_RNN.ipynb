# %% [markdown]
# # CS155 Project 3 Recurrent Neural Networks
# In this notebook, we generate Shakespeare poems using LSTM-RNNs.

# %% [markdown]
# ## Functions

# %%
import re
import pandas as pd
from keras.models import load_model
import WilliamRNN as willr
from nltk.tokenize import SyllableTokenizer

Ts = [1.5,0.75,0.25]
Nunits = [100,150,200]

def LoadRNNs(Nsemi):
    iT = 0
    models = []
    for Nunit in Nunits:
        model_Ts = []
        iT = 0
        for T in Ts:
            model = load_model('models/Nsemi'+str(Nsemi)+'/'+'rnn_iT_'+str(iT)+'_units_'+str(Nunit)+'.h5')
            iT += 1
            model_Ts.append(model)
        models.append(model_Ts)
    return models

def GetSyllablesDict():
    df = pd.read_csv('data/Syllable_dictionary.txt',header=None)
    df_vals = df.values
    syl_dic = {}
    syl_dic_E = {}
    for val in df_vals:
        dics = val[0].split()
        if len(dics) == 2:
            syl_dic[re.sub(r'[^\w]','',dics[0])] = int(dics[1])
        elif len(dics) == 3:
            try:
                syl_dic[re.sub(r'[^\w]','',dics[0])] = int(dics[2])
                eIDX = 1
            except:
                syl_dic[re.sub(r'[^\w]','',dics[0])] = int(dics[1])
                eIDX = 2
            syl_dic_E[re.sub(r'[^\w]','',dics[0])] = int(dics[eIDX].strip('E'))
    return syl_dic,syl_dic_E

def GetPoem(models,Ns):
    SSP = SyllableTokenizer()
    will = willr.William(seq_length=41,Nsemi=Ns)
    syl_dic,syl_dic_E = GetSyllablesDict()
    for i in range(len(Nunits)):
        for j in range(len(Ts)):
            model = models[i][j]
            print('####### LSTM-RNN: semi-redundant sequences with n = '+str(Ns)+' #######')
            print('T = '+str(Ts[j])+' and Nunit = '+str(Nunits[i]))
            input_c = list("shall i compare thee to a summer's day?\n")
            text = will.GenerateAIpoem(input_c,model,1000)
            lines = [line for line in text.split('\n')]
            Nsyl_list = []
            for l in range(len(lines)):
                line = lines[l]
                Nsyl = 0
                line_s = line.split()
                for word in line_s:
                    word = re.sub(r'[^\w]','',word).lower()
                    try:
                        if i != len(line):
                            Nsyl += syl_dic[word]
                        else:
                            Nsyl += syl_dic_E[word]
                    except:
                        if word != '':
                            Nsyl += len(SSP.tokenize(word))
                if Nsyl <= 9:
                    print('(#syllables  '+str(Nsyl)+')',line)
                else:
                    print('(#syllables '+str(Nsyl)+')',line)
                Nsyl_list.append(Nsyl)
                if l == 13:
                    break
            mean = sum(Nsyl_list)/len(Nsyl_list) 
            variance = sum([((x-mean) ** 2) for x in Nsyl_list])/len(Nsyl_list)
            std = variance ** 0.5
            print('Average #syllables: '+str(mean))
            print('Standard deviation #syllables: '+str(std))
            print('#############################################################','\n')
    pass
            
def GetErrors(models,Ns):
    will = willr.William(seq_length=41,Nsemi=Ns)
    for i in range(len(Nunits)):
        for j in range(len(Ts)):
            model = models[i][j]
            print('####### LSTM-RNN: semi-redundant sequences with n = '+str(Ns)+' #######')
            print('T = '+str(Ts[j])+' and Nunit = '+str(Nunits[i]))
            model.fit(will.X,will.y,epochs=1,verbose=2)
            print('#############################################################')
    pass

def GetSinglePoem(model,input_c,Ns):
    SSP = SyllableTokenizer()
    will = willr.William(seq_length=41,Nsemi=Ns)
    syl_dic,syl_dic_E = GetSyllablesDict()
    print('############### My favorite poem ###############')
    text = will.GenerateAIpoem(input_c,model,1000)
    lines = [line for line in text.split('\n')]
    Nsyl_list = []
    for l in range(len(lines)):
        line = lines[l]
        Nsyl = 0
        line_s = line.split()
        for word in line_s:
            word = re.sub(r'[^\w]','',word).lower()
            try:
                if i != len(line):
                            Nsyl += syl_dic[word]
                else:
                            Nsyl += syl_dic_E[word]
            except:
                if word != '':
                    Nsyl += len(SSP.tokenize(word))
        if Nsyl <= 9:
            print('(#syllables  '+str(Nsyl)+')',line)
        else:
            print('(#syllables '+str(Nsyl)+')',line)
        Nsyl_list.append(Nsyl)
        if l == 13:
            break
    mean = sum(Nsyl_list)/len(Nsyl_list) 
    variance = sum([((x-mean) ** 2) for x in Nsyl_list])/len(Nsyl_list)
    std = variance ** 0.5
    print('Average #syllables: '+str(mean))
    print('Standard deviation #syllables: '+str(std))
    print('#################################################','\n')
    pass

# %% [markdown]
# ## Load LSTM-RNNs (trained with semi-redundant sequences with n = 5, 10)

# %%
models1 = LoadRNNs(1)
models5 = LoadRNNs(5)
models10 = LoadRNNs(10)

# %% [markdown]
# ## Generate poems using LSTM-RNNs

# %%
GetPoem(models1,1)
# Out:
# ####### LSTM-RNN: semi-redundant sequences with n = 1 #######
# T = 1.5 and Nunit = 100
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables 15) when thou shall summer's that which the world so de.' when the satf's spent.
# (#syllables 12)   to bution bear detime to him out of true,
# (#syllables 10) and the world's from the sumper to the sake,
# (#syllables 10) and then those all the worls more than the dear.
# (#syllables 10) which where i have so strangle as that seen,
# (#syllables 11) and theneir merally mustant warthing bear
# (#syllables  9) which now are my love to the sides kear
# (#syllables  9) with the world's from the to mour would may.
# (#syllables  9)   the swell of thy love and love's frown stand
# (#syllables 11)   to kingers maded a contross that thou art,
# (#syllables 10)   and the world with to the sabs of spatce.
# (#syllables 13) it self the worsh to show the world woul slave some for least,
# (#syllables 10) when thou form of thy love and love and see,
# Average #syllables: 10.642857142857142
# Standard deviation #syllables: 1.6303874586447609
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 1 #######
# T = 0.75 and Nunit = 100
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables  9) why should every breathe there of the heart,
# (#syllables 12) which like a continues more may other doth die,
# (#syllables 10) thy piberseabers beauteous by thy die,
# (#syllables 11) fererfuce his reparthest thy self are,
# (#syllables  9) and they more that i shall things of more
# (#syllables 11) on thee to this shall each respeary wearth: now,
# (#syllables  8) and i am stand again me fair,
# (#syllables 11)   and presence majessed, now all alone seem,
# (#syllables  8) thy heaven shall sweet smill regquing,
# (#syllables 11) and therefore mayst being but to thee heir die,
# (#syllables  9) frer straight thy sweet perpase your deem.
# (#syllables  9)   this thought, and the treasure of thy days,
# (#syllables 10) and i say this will it made of my state!
# Average #syllables: 9.857142857142858
# Standard deviation #syllables: 1.1866605518454392
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 1 #######
# T = 0.25 and Nunit = 100
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables 11) thou art menace within the world will knows,
# (#syllables  9) and there by thee the old now this groangnts,
# (#syllables 10) and to the world, and look at heaven's so,
# (#syllables  9) that health's gll ren, thy beauty doth gent,
# (#syllables 11) the hangs and wark natks bud the life heaven face,
# (#syllables 10) but therefore that i was time's love endmem.
# (#syllables 11)   then my love sweet thank, and she loved forswrite,
# (#syllables 12) and stors words of thy beauty's form is all the gust,
# (#syllables 11) nor bear she lacher or the prize of noting.
# (#syllables 10) the combs wors what ills shall be muse's rain
# (#syllables 12) thy franthed, in and dear woe,   be so arixain,
# (#syllables 12) whillest i will comelnessing, and their he time,
# (#syllables 10) and loves afterats of you light she give,
# Average #syllables: 10.571428571428571
# Standard deviation #syllables: 0.9793792286287207
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 1 #######
# T = 1.5 and Nunit = 150
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables 11) and heaven in his scope to the world by me;
# (#syllables 11)  here when she waternal guied me, so freen.
# (#syllables 10)   and in their praises her with the world pain.
# (#syllables  9) that which thou art movited of live,
# (#syllables 10) with love thee are but sweets to the worloust,
# (#syllables 12) and to thy self thy beauty do i encermet;
# (#syllables 11) but thou art confining once mised shall stone,
# (#syllables 11) that i speay which in their shadowed know.
# (#syllables 10)   and so it the world with thee i frow sweet.
# (#syllables  9) that thou art more retter face shamed, be.
# (#syllables  9)   and thou thy self thy love and the world,
# (#syllables  9) and that the worth's for of thee for me,
# (#syllables 10) under that i should can your self art so,
# Average #syllables: 10.142857142857142
# Standard deviation #syllables: 0.9147320339189784
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 1 #######
# T = 0.75 and Nunit = 150
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables 10) thou art me seen, o'er my grownath doth grow.
# (#syllables 11) though in seture one of thy adveried
# (#syllables  9) grow his spitits to thou know'st thy ears?
# (#syllables  9) but they do bord with thee, and your fail
# (#syllables 10) as one earth and take and barren will be,
# (#syllables 12)   to eaced thee remembered might true smale.
# (#syllables 11)   i will not praising so, have he will if do,
# (#syllables 11)   so like a second site abictered,
# (#syllables 10) knowing that the thing hometh give and soor.
# (#syllables  9) feed favour love may my love away.
# (#syllables 11)   all thy heart the bloody picty did ewe:
# (#syllables 12) i in thy praise his objestight the earchst recteal.
# (#syllables 10) yet beauty beauteous and inflatirs all,
# Average #syllables: 10.357142857142858
# Standard deviation #syllables: 0.9715336077668175
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 1 #######
# T = 0.25 and Nunit = 150
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables 10) thou art but shadow lead ere return sweet,
# (#syllables 10) that in this which it were no motion slow,
# (#syllables 11) they live sweet brass we abondatted ever,
# (#syllables 13) that i in hang you presemutsed for me his line?
# (#syllables 11) the states are loan for womy still to eart,
# (#syllables  9) nor do i none, not thou pride will, crow'st,
# (#syllables 12) anver in my mistress' eye love's seen baring dry,
# (#syllables  9) or thine of things thine as your self still,
# (#syllables  8)   and your beauty's dead fleece made and
# (#syllables  9) which no gucle the passed fame drustends
# (#syllables 12) that beauty to dwed am strayee summer sight,
# (#syllables 11) then mougle a sad if this thy goner gut.
# (#syllables  9) make bend, and trutly vantage's call,
# Average #syllables: 10.285714285714286
# Standard deviation #syllables: 1.3850513878332367
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 1 #######
# T = 1.5 and Nunit = 200
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables  8) then gives thy self absent for me,
# (#syllables 10) it can a fairent, that bear her from thee:
# (#syllables 10) the right, that of the sun's ences and own
# (#syllables 11) in did proge whose comments some devile?
# (#syllables 10) why should i not the thangure of thine,
# (#syllables 10) and they see that leaded of thine, me are,
# (#syllables 13)   then my flambs others' beauty's wook of brame remain
# (#syllables  9) gently fear ron scoppier each from thee,
# (#syllables 10) in own dream dislatered could truth shame,
# (#syllables 11) for that rosing worthing offence image now.
# (#syllables  8)   your all thy love to this sub'dring,
# (#syllables 10)   thou hard'st thy love with unthore the still,
# (#syllables 10) and therevershuns ot conse tongue tough,
# Average #syllables: 10.0
# Standard deviation #syllables: 1.1952286093343936
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 1 #######
# T = 0.75 and Nunit = 200
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables 11) thou art more loving of age'st art or men,
# (#syllables 13)   and in questrof still with them, and yet's jowel his one,
# (#syllables 10) and for thy self-doined, where it shall be.
# (#syllables  9)   then my beauty's with that wain she short,
# (#syllables 11) whehochough that was shall geater can of state,
# (#syllables  9) or state it love to thy way where out
# (#syllables 11) fleth do i pier, it receives from the disgrace:
# (#syllables  9) nor praise speaking breath then you before,
# (#syllables 10) in sequent toims no one is their priden.
# (#syllables 10)   and they it we prountent my riper be.
# (#syllables 11)   then aways you woo' which thou then my readen,
# (#syllables  9) for that i hast believe men commen
# (#syllables 12) at me black night of love, in thee i do contend.
# Average #syllables: 10.357142857142858
# Standard deviation #syllables: 1.171515676204052
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 1 #######
# T = 0.25 and Nunit = 200
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables 10) thou art more lovely and more temperate:
# (#syllables 12) rough winds doside his tracariess of at fies,
# (#syllables 10) whose stall grace in warth of thine, her create,
# (#syllables 10) that have i not locked up in any chest,
# (#syllables 10) save where thou art not, though i feel thou art,
# (#syllables 10) within the gentle closure of my breast,
# (#syllables 11) for being vurse in this good to this shape,
# (#syllables 11) whilst he is, tellive growin that loving,
# (#syllables 11) peins how there be beloved as a will me,
# (#syllables 11)   birdren outare much is canker mine eye,
# (#syllables 12) as i not fave, or sounded sickly is out,
# (#syllables 10)   and they as farth time's bectuse do nend,
# (#syllables 10) than of your graces and your gifts to tell.
# Average #syllables: 10.571428571428571
# Standard deviation #syllables: 0.7284313590846835
# #############################################################

# %%
GetPoem(models5,5)
# Out:
# ####### LSTM-RNN: semi-redundant sequences with n = 5 #######
# T = 1.5 and Nunit = 100
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables 11) for whiness that is mert love when as whate,
# (#syllables  8) and remoch from thee frost have worth,
# (#syllables 10) and may you lepptes with hath that i low,
# (#syllables 16) nay what see thou death fort mine wairiny beautyoy beauty,
# (#syllables  9) that that liss gle for see that frim might?
# (#syllables 12) doth my body day my orlons of though sweetes,
# (#syllables  9) that tour wells of thee dord eyes say lay,
# (#syllables 11) that lend then in enore thou hemmings mine,
# (#syllables  7) and this for that wheredy,
# (#syllables 11) and trisur surt tingur waired wild thy prams,
# (#syllables 13) at this worder that my lofor thou vertured shand,
# (#syllables 10) since me that is meater'se of thy see,
# (#syllables 10) and look in a love, the it love in net,
# Average #syllables: 10.5
# Standard deviation #syllables: 2.1297216451250818
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 5 #######
# T = 0.75 and Nunit = 100
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables 10) wheneaker the porm memied thou meqried,
# (#syllables 10) when i walk old all the more triel, the stres,
# (#syllables 10) and lookent bed facest you love's my heart,
# (#syllables  9) for gaves of buth nownfact beaut,
# (#syllables 12) what i wattion your are to poinide of fill,
# (#syllables 10) and summ me tordan where athoughts all to
# (#syllables  2) soun still,
# (#syllables 13) and sume it mold that hend lowils i whthiring thee,
# (#syllables 11)   tor thich groet compouty of the fillere.
# (#syllables 11)   thoue by pooys, in hath repaincyed and.
# (#syllables 15) and slay frace see is thy praiourngos d withrngrigess:
# (#syllables 11)   beelifight my sacofan wince in thee,
# (#syllables 11) thy senfor thy staire of may dear remort.
# Average #syllables: 10.357142857142858
# Standard deviation #syllables: 2.741405866056499
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 5 #######
# T = 0.25 and Nunit = 100
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables 10) and summen's sunsen adcaten men thee,
# (#syllables  6) she prasurs the prousso
# (#syllables 12)   beary, frich paringg of our in adced fraan,
# (#syllables 11) as in ever thou hell i wor mort and thee,
# (#syllables  9) the worlh whides to beart than mine spen,
# (#syllables 12) astat i cast love, no elesited ushad.
# (#syllables 15) our i foo my niffare the's some, hath i sell not bell,
# (#syllables 17) merim serwitined be to wive, and sweet.  if lick you trucke?
# (#syllables  9) of of they his groms dey tougus red,
# (#syllables 12) and shoun thy hear requited dor thum my sobjed,
# (#syllables 10) the connoth, all crines, and which not ben
# (#syllables  4) i swornks ny pace,
# (#syllables 10)   for thee thou dear self sumbored, mere,
# Average #syllables: 10.5
# Standard deviation #syllables: 3.1339158526400435
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 5 #######
# T = 1.5 and Nunit = 150
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables 12) in the romine east then belambels ose,
# (#syllables 10) to but thou ar your ored, you thy woeld,
# (#syllables  8)   whiter she worlds to thee to mend,
# (#syllables  9) staingnos ane out aspeartion shout:
# (#syllables 13) not thou shald she love when anby cont, in eversed,
# (#syllables 10) yo traticl a love appainy os batt,
# (#syllables 10) and betang us then wets mobe, which eves,
# (#syllables 14) detervenst this sweet beaution on pasest, see, seld great,
# (#syllables  8) to hell meastyes beasting mank own
# (#syllables  9) thy bele fair which the woulds riscrieg:
# (#syllables 11) i cand and sumpeired of more trappliong beig,
# (#syllables 10) whingins to hell owe to betimered,
# (#syllables 11)   but in this sacceries the vorts all the wong,
# Average #syllables: 10.357142857142858
# Standard deviation #syllables: 1.6736249305514257
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 5 #######
# T = 0.75 and Nunit = 150
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables 12) the love i live the lover ow to the tive,
# (#syllables 12) whis my love, that wirest thou the time's good deming,
# (#syllables 12) but my silf the lover she of to thee do but:
# (#syllables  4) sich no fainstor,
# (#syllables 11) a do the love's sunks summering winchesent,
# (#syllables 11)   who i store that rids shemes to the love's facts
# (#syllables 11) i acaintine priencledsereds that sin,
# (#syllables 12) a cumm chine brivids trethor sace she live,
# (#syllables  9)   thet my froothou, and frowond the love,
# (#syllables 12) the and thet arl aghe that the mome it love,
# (#syllables 11) the love's ficker when when a see po the dey,
# (#syllables  0) .
# (#syllables 14) at thet i will restole, atar will more meader woll.
# Average #syllables: 10.071428571428571
# Standard deviation #syllables: 3.5549620394655155
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 5 #######
# T = 0.25 and Nunit = 150
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables 13) d that our sive an then withing the ear all.
# (#syllables 14)   or caulin gut shy liver whums in neaved for her sin,
# (#syllables 12)   to se sin chet pack minge swieteres beres,
# (#syllables 12) that cangot be for thee wothis so thee to king,
# (#syllables 14) and eyest in thy self cun doth fiors, the reay the stoll,
# (#syllables 12) whilling your like (howe love what for they sone,
# (#syllables 12) a doth foring the to foulds, and hosters ant thee,
# (#syllables 11) thou dear doth meres to fingue of lowe,
# (#syllables 13) or prase ot the hutber anotheres so thee.
# (#syllables 10)   and a thene, shat the wong of thy stee,
# (#syllables 12) geat do hold so pripiviche and as art will,
# (#syllables  6) than you love woth soone,
# (#syllables  9) as loty love hat her is mure:
# Average #syllables: 11.428571428571429
# Standard deviation #syllables: 2.0603150145508513
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 5 #######
# T = 1.5 and Nunit = 200
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables 12) thy seefo may beafty fall watican it live,
# (#syllables 11) and all the died, and the uppain of measure.
# (#syllables 12)   thou betumy or my have i manks of be groan;
# (#syllables 10) hould i am alther and the prast, and fouth,
# (#syllables  5) sube paid your mearth,
# (#syllables 11) and and yet i not, and eyes tr me thuse,
# (#syllables 10) thy fourts and thy bearour ay may that deart,
# (#syllables  9) and thinks not thou have me formerts one,
# (#syllables 11) is lot ey seefr when an amber, of ell mead:
# (#syllables  9) not shouls rath in huring the reding,
# (#syllables  9) which shall to mends are heaven thear glvel:
# (#syllables 11) me that wairs of this flome mures or mand:
# (#syllables 10) bub time do with mure of shay gladder,
# Average #syllables: 10.0
# Standard deviation #syllables: 1.6903085094570331
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 5 #######
# T = 0.75 and Nunit = 200
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables 14) nor have all whrows thy so lowe what wertestay in me,
# (#syllables 14)   then of this, glaise i pride tommmmen deceepitured,
# (#syllables  9) and then in the best whe world comes dee,
# (#syllables 14) for i hin swirld i whut sing   and ede, uran ot losk,
# (#syllables 11) he lint, then forghte ho dortull of ele,
# (#syllables 10) and weru dearthough that thy bemort wors,
# (#syllables 10) thy i live will me to bother yot frees,
# (#syllables 11) that may e praring thou att doth lovely gloar,
# (#syllables 15) which hubbeay fair weresime in my ade beauty.
# (#syllables 11)   then of my hestrd in eyes so paite to be.
# (#syllables 13) the lives thy seepul cam a carer mare eress
# (#syllables 10) atsing on yes ryob hat seep do commert:
# (#syllables 10) day suce are brtalls foo showe self brownd,
# Average #syllables: 11.571428571428571
# Standard deviation #syllables: 1.9166296949998196
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 5 #######
# T = 0.25 and Nunit = 200
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables 16) nor that the cames and evesure to ame worth nove,
# (#syllables 11)   for the time upon call i love that sare,
# (#syllables 11) as vend that con tell mume spenks ounder art.
# (#syllables 11) the fairy of that sair storn othe surmer,
# (#syllables  8) and prach therefore is thy beepent,
# (#syllables 10) when your seef ounds ad im dost prof mempers
# (#syllables 14)   where thee bet eys ridesereceed of your freasured,
# (#syllables 10)   thoughthence sammer drow stounded of trim,
# (#syllables  8) nor ampering of thee dost leave,
# (#syllables 11) up in thy belf beth restall mume bringlest,
# (#syllables 12)   then all the reser-subut of thines rown steent.
# (#syllables 12)   wild thy bedow i confer each do his sine,
# (#syllables  9) ear it thus roustion yes richtere:
# Average #syllables: 10.928571428571429
# Standard deviation #syllables: 2.086154552358605
# #############################################################

# %%
GetPoem(models10,10)
# Out:
# ####### LSTM-RNN: semi-redundant sequences with n = 10 #######
# T = 1.5 and Nunit = 100
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables 10) whan thou art buthtesull be tough mery,
# (#syllables 14) no fouldy premen eabtedo not fan rome tous groegh,
# (#syllables 14) for with mumy lo seepich they reme to tee sume,
# (#syllables 10) and your nee focke tress a vill noth live,
# (#syllables  3)   leabey look,
# (#syllables 15) ond not tat in i ne rind, and seeft suclift cate sime,
# (#syllables  3) and your nee,
# (#syllables 12) soise sace and suemen enouchich then frown,
# (#syllables 10) when well fay folln or mand and ther foren,
# (#syllables  8) that which stool deather ene lays,
# (#syllables 13) and searing thit woyns tide's ove ar time is fore.
# (#syllables  5)   in me sel sine,
# (#syllables 10) soresting thou do spilens in ton end,
# Average #syllables: 9.785714285714286
# Standard deviation #syllables: 3.7450647796909515
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 10 #######
# T = 0.75 and Nunit = 100
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables 11) thay i from me in me fich lothist onfert,
# (#syllables 12) and ald now hepor and apur apass solfthre,
# (#syllables 10) and beaur a ther for me i not will,
# (#syllables 13)   whise ondering to am abon flove llissint,
# (#syllables 12) eiving that thin, and as love, whise onker, thee,
# (#syllables 10)   for then mond while of selfon inget wey,
# (#syllables  8)  have i sheel this sook swith groan shish
# (#syllables 10) do that mamy houp to the with the worl,
# (#syllables 14)   in thy seeppy i memmers solltr my solfthar youn seal.
# (#syllables 10)   from this ur not woll my mome which grost?
# (#syllables 11) ot be on meriof that wher on me be stell,
# (#syllables 11) bu doow blentheren my shell-do to am worn.
# (#syllables 12) ane see to aw worn whish doo ase of thee,
# Average #syllables: 11.0
# Standard deviation #syllables: 1.4638501094227998
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 10 #######
# T = 0.25 and Nunit = 100
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables  5) seeken do ell-sood.
# (#syllables 13) the mine appiotempen yeer may i do eve,
# (#syllables 13) whine farse spiigiven wownt hive des filse,
# (#syllables  3) whet if bind,
# (#syllables 12) the fingsh my lef a ow thenedust to the sart,
# (#syllables 12) and that hear ard is thise sweling ferement,
# (#syllables 14) but i moun fanceriig chuert of bucties devedesteet,
# (#syllables 10) wer then iw will counder is liss lese,
# (#syllables 12) the beand or me is thy seart thy self eremort.
# (#syllables 11) that thea auly st my semf coodds, any my,
# (#syllables 10) and weeling on ele mome deast thyes
# (#syllables  8) on no eremple ou doan thee,
# (#syllables 16)   in ethy soof thou hear the loves wheserer's ape torerent.
# Average #syllables: 10.642857142857142
# Standard deviation #syllables: 3.329674863087619
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 10 #######
# T = 1.5 and Nunit = 150
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables  7) no bidst on hapl hures prrand,
# (#syllables 19) but an i thou  lofils bustoug they live which thee atcoud trou thy endouced
# (#syllables 23) oun thee that warn you live whence that wor dour shaity in all-tour as actile werfurceras,
# (#syllables  5) i lace i the sor,
# (#syllables 30) and ere me ion my semmoun norewers of the praciou bed thus se touber day blave, which hathou, that werr much find:
# (#syllables 10)   but i trou m mess of batse spert hand,
# (#syllables 11) wereses doow shates in my meart be there,
# (#syllables 11) too that mory live which for then do haur nor,
# (#syllables 11) and hougut of the with sweet be for bras doss,
# (#syllables 18) in thet mo good blacyess reaut be the pras achun of bay leases so
# (#syllables  0)
# (#syllables  5) in in thy seef's mang:
# (#syllables 19)   thou hast the fand the bear which for cand and atiougst lave, when awcerme,
# Average #syllables: 12.785714285714286
# Standard deviation #syllables: 7.784403559394273
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 10 #######
# T = 0.75 and Nunit = 150
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables  0)
# (#syllables 12) or that in that wor deas mind that mear hishs despot.
# (#syllables  8) faindd fraccm if con thee lotr oon thee,
# (#syllables 12) do to be uary or thime in all that has,
# (#syllables 11) thing the self in uticets wetk food thouldshe,
# (#syllables 12) andee's are wared my ind to steees so koon,
# (#syllables  9) and hal ather love hem hounds an thee,
# (#syllables 10) the mou doow sealt mime doth mey ond houdds,
# (#syllables 11) wiesting abnen love, and ele me more sway .
# (#syllables  9) oo art which ghid love and redst and hant,
# (#syllables  9) shangss in love a watters licsiggtd doow,
# (#syllables 15) and plling or mam is mort what weroud sto mo fach whith thou dstill,
# (#syllables 11) woe sey to mee pricing of each if thee dscent,
# Average #syllables: 9.928571428571429
# Standard deviation #syllables: 3.2395829915567336
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 10 #######
# T = 0.25 and Nunit = 150
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables 13) foon encuiceited thy self come the live, a ded and,
# (#syllables 10) but the semem so sorggt'se sey love's sind.
# (#syllables  9) that frommel the to tome's peisen
# (#syllables  9) in that the love's sill shear not my see.
# (#syllables 14) thy preise best beauty's seemeng soneate's lose of hat,
# (#syllables  7) but subless sill to howe,
# (#syllables  9) that from he my in thy self me hide,
# (#syllables 14) that fremmen dood that coult thy self moue od thee so stang,
# (#syllables  9) and have exames sissuess soee,
# (#syllables 10)   that hat the s storggese of thee shee,
# (#syllables 11)   fee shatch thee mecaightous sseest visteevere,
# (#syllables 10) whele what de prinpring they soll not hound,
# (#syllables  9) but that eremon lease of llase,
# Average #syllables: 10.285714285714286
# Standard deviation #syllables: 1.979486637221574
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 10 #######
# T = 1.5 and Nunit = 200
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables  9) bring that wore hary bendering.
# (#syllables  4)  ou love's eeps see,
# (#syllables  8)   fach as as not fals spitised.
# (#syllables  9)   and you shewhing fin it cliss sweet be.
# (#syllables  6)   then thou shell-sing and houk,
# (#syllables  9)   then as as mess and loves not be oll,
# (#syllables 10) to belf in the eer-ou dost velthere.
# (#syllables 14) thing hith more speaker bragith nome's seepline evert
# (#syllables 13) wothing my lome, the pering the beauty offand:
# (#syllables  9) oot shived for and hat sast and pasts
# (#syllables  5) chine oundeding,
# (#syllables 16) tay beand dode hilf the saurty sheor hapat past wishornd you art.
# (#syllables  9) i then thou shealves of thy semmok,
# Average #syllables: 9.357142857142858
# Standard deviation #syllables: 3.175962010773673
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 10 #######
# T = 0.75 and Nunit = 200
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables 10) not in the beaker semmes son ee iond,
# (#syllables 11) d and hat then tho e prore chiis steee,
# (#syllables 14) for thou the revind for the irnd distelussin me mong:
# (#syllables 10) d's at they love shat were sondon deapar,
# (#syllables 10) and thee so shlle siave uachs of hate shall,
# (#syllables 10) whe cougrtceiligg tan eepe.t famm hit the,
# (#syllables 14) the graight the preceide that wor thou tho both of your mear,
# (#syllables 11) and letsen fomm his appacaike th theerson
# (#syllables 10)  on the in the beard a llt me pore,
# (#syllables 11) and lotes springet io he conded an thee,
# (#syllables  9) and deess of thy woeld best eneer she.
# (#syllables 12) to hemm simm ene semforddetherein as aysh
# (#syllables  7) my s easserss on your fart,
# Average #syllables: 10.642857142857142
# Standard deviation #syllables: 1.7569105537498348
# #############################################################
#
# ####### LSTM-RNN: semi-redundant sequences with n = 10 #######
# T = 0.25 and Nunit = 200
# (#syllables 10) shall i compare thee to a summer's day?
# (#syllables 12) of that whor and co me the lives  is doresse,
# (#syllables 11) and deting houn ail thy welfsh mock on elle,
# (#syllables 11) bud i (houre orthengeded blatker brong.
# (#syllables  1)   fress,
# (#syllables 13) ind budond freem is an, and ey she thee do doth rear,
# (#syllables 12) han had uthat the stmmerewghtoof llle my praite,
# (#syllables  6)  hich shor tobe so wrong;
# (#syllables 12) doy you ir hill to the lover woth wheesest beak,
# (#syllables 10) or mer me ir thearess'aiker try sind
# (#syllables 12) tore art or thy sinf livv's w mond saight fros mo,
# (#syllables 10) in the piringn dand wor doy betull pith,
# (#syllables 13) that cow thou well be upleing of and thy mroughtiof sree:
# (#syllables 10) sed aod then memmer plothth tho lov'st commend,
# Average #syllables: 10.214285714285714
# Standard deviation #syllables: 3.0747490357186975
# #############################################################

# %% [markdown]
# ## Obtain accuracies of each LSTM-RNN

# %%
GetErrors(models1,1)
# Out:
# ####### LSTM-RNN: semi-redundant sequences with n = 1 #######
# T = 1.5 and Nunit = 100
# Epoch 1/1
#  - 69s - loss: 1.0131 - accuracy: 0.6738
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 1 #######
# T = 0.75 and Nunit = 100
# Epoch 1/1
#  - 77s - loss: 0.8428 - accuracy: 0.7230
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 1 #######
# T = 0.25 and Nunit = 100
# Epoch 1/1
#  - 87s - loss: 0.7011 - accuracy: 0.7655
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 1 #######
# T = 1.5 and Nunit = 150
# Epoch 1/1
#  - 116s - loss: 0.9248 - accuracy: 0.7009
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 1 #######
# T = 0.75 and Nunit = 150
# Epoch 1/1
#  - 114s - loss: 0.3428 - accuracy: 0.8800
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 1 #######
# T = 0.25 and Nunit = 150
# Epoch 1/1
#  - 112s - loss: 0.2113 - accuracy: 0.9273
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 1 #######
# T = 1.5 and Nunit = 200
# Epoch 1/1
#  - 156s - loss: 0.3747 - accuracy: 0.8716
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 1 #######
# T = 0.75 and Nunit = 200
# Epoch 1/1
#  - 159s - loss: 0.1318 - accuracy: 0.9565
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 1 #######
# T = 0.25 and Nunit = 200
# Epoch 1/1
#  - 152s - loss: 0.0620 - accuracy: 0.9806
# #############################################################

# %%
GetErrors(models5,5)
# Out:
# ####### LSTM-RNN: semi-redundant sequences with n = 5 #######
# T = 1.5 and Nunit = 100
# Epoch 1/1
#  - 35s - loss: 0.1992 - accuracy: 0.9450
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 5 #######
# T = 0.75 and Nunit = 100
# Epoch 1/1
#  - 36s - loss: 0.0928 - accuracy: 0.9760
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 5 #######
# T = 0.25 and Nunit = 100
# Epoch 1/1
#  - 36s - loss: 0.0078 - accuracy: 0.9999
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 5 #######
# T = 1.5 and Nunit = 150
# Epoch 1/1
#  - 44s - loss: 0.1805 - accuracy: 0.9515
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 5 #######
# T = 0.75 and Nunit = 150
# Epoch 1/1
#  - 45s - loss: 0.0913 - accuracy: 0.9822
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 5 #######
# T = 0.25 and Nunit = 150
# Epoch 1/1
#  - 44s - loss: 7.8330e-04 - accuracy: 1.0000
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 5 #######
# T = 1.5 and Nunit = 200
# Epoch 1/1
#  - 56s - loss: 0.0381 - accuracy: 0.9979
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 5 #######
# T = 0.75 and Nunit = 200
# Epoch 1/1
#  - 58s - loss: 0.0018 - accuracy: 1.0000
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 5 #######
# T = 0.25 and Nunit = 200
# Epoch 1/1
#  - 56s - loss: 0.0030 - accuracy: 1.0000
# #############################################################

# %%
GetErrors(models10,10)
# Out:
# ####### LSTM-RNN: semi-redundant sequences with n = 10 #######
# T = 1.5 and Nunit = 100
# Epoch 1/1
#  - 19s - loss: 0.1596 - accuracy: 0.9660
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 10 #######
# T = 0.75 and Nunit = 100
# Epoch 1/1
#  - 18s - loss: 0.0339 - accuracy: 0.9999
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 10 #######
# T = 0.25 and Nunit = 100
# Epoch 1/1
#  - 18s - loss: 0.0039 - accuracy: 1.0000
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 10 #######
# T = 1.5 and Nunit = 150
# Epoch 1/1
#  - 23s - loss: 0.0167 - accuracy: 1.0000
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 10 #######
# T = 0.75 and Nunit = 150
# Epoch 1/1
#  - 23s - loss: 0.0053 - accuracy: 1.0000
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 10 #######
# T = 0.25 and Nunit = 150
# Epoch 1/1
#  - 22s - loss: 0.0127 - accuracy: 0.9999
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 10 #######
# T = 1.5 and Nunit = 200
# Epoch 1/1
#  - 27s - loss: 0.0388 - accuracy: 0.9992
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 10 #######
# T = 0.75 and Nunit = 200
# Epoch 1/1
#  - 28s - loss: 6.8513e-04 - accuracy: 1.0000
# #############################################################
# ####### LSTM-RNN: semi-redundant sequences with n = 10 #######
# T = 0.25 and Nunit = 200
# Epoch 1/1
#  - 28s - loss: 1.2591e-04 - accuracy: 1.0000
# #############################################################

# %% [markdown]
# ## My favorite poem

# %%
GetSinglePoem(models1[2][1],list("i can't stop this feeling, deep inside of me,\n"),1)
# Out:
# ############### My favorite poem ###############
# (#syllables 12) i can't stop this feeling, deep inside of me,
# (#syllables 13) liquing in thine eye bate my gross do bent,
# (#syllables 11) by advich controw it so forgot a lick,
# (#syllables 14) i may begues, that thou mayst have those their dear deem,
# (#syllables 12) but what of thee, and for thy self art pleasure,
# (#syllables 12)   but daves more blest thee vanticing crossed,
# (#syllables 12) the poor of this proud come his rick) compite!
# (#syllables  9) hoon, thou the sweetest broods on thee it;
# (#syllables 13) both from thy fair) to flatterer thou abundarness,
# (#syllables 11) right despised strangle and love doth seen,
# (#syllables 12) all stars in thy heart is love therefore,
# (#syllables 12)   they may detiven makes and soonur all wrong.
# (#syllables 13) i will not polis conforned af your rarse,
# (#syllables 14) their hold and then more in hope's all, with men's eyes,
# Average #syllables: 12.142857142857142
# Standard deviation #syllables: 1.245399698154478
# #################################################
